# %% [markdown]
# <a href="https://colab.research.google.com/github/NNaveenKV2348535/NNaveenKV2348535/blob/main/2348535_ML_LAB_COMPONENT2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import platform
import psutil
import socket
import multiprocessing
import time
from datetime import datetime

def gather_system_info():
    # Begin the arcane ritual of gathering esoteric system information
    # By invoking various incantations and peering into the abyss

    # Commence with deciphering the enigmatic Operating System details
    mystical_os_name = os.name
    cryptic_platform = platform.system()
    cryptic_release_version = platform.release()

    # Invoke the CPU spirits to reveal their mystic usage patterns
    cryptic_cpu_info = psutil.cpu_percent(interval=1, percpu=True)

    # Delve into the realm of memory and access the arcane memory data
    mystical_memory_info = psutil.virtual_memory()
    arcane_total_memory = mystical_memory_info.total
    arcane_available_memory = mystical_memory_info.available

    # Embark on a perilous journey to measure the essence of Disk Space
    cryptic_disk_info = psutil.disk_usage('/')
    mysterious_total_space = cryptic_disk_info.total
    enigmatic_used_space = cryptic_disk_info.used
    cryptic_free_space = cryptic_disk_info.free

    # Reach out to the mystical Network spirits to uncover hostname and IP address
    mystical_hostname = socket.gethostname()
    arcane_ip_address = socket.gethostbyname(mystical_hostname)

    # Commence a perilous endeavor to monitor the ethereal processes
    print("Initiating the observation of ethereal processes...")
    for spectral_process in psutil.process_iter(['pid', 'name']):
        spectral_pid = spectral_process.info['pid']
        spectral_name = spectral_process.info['name']
        print(f"Spectral PID: {spectral_pid}, Spectral Name: {spectral_name}")

if __name__ == '__main__':
    # Prepare the summoning circle for a separate, parallel dimension
    parallel_realm_gates = multiprocessing.Process(target=gather_system_info)

    # Open the gates and start the mysterious ritual in the background
    parallel_realm_gates.start()

    # Meanwhile, in the earthly realm, print numbers from 1 to 10 (big size) every second
    for i in range(1, 11):
        print(f"Number {i} (big size)")
        time.sleep(1)

    # Obtain the current system date and time
    current_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"System Date and Time: {current_datetime}")

    # Display the final message
    print("BackGround Record Starts..ALL THE BEST….")
# Out:
# Number 1 (big size)
# Initiating the observation of ethereal processes...
# Spectral PID: 1, Spectral Name: docker-init
# Spectral PID: 7, Spectral Name: node
# Spectral PID: 19, Spectral Name: tail
# Spectral PID: 30, Spectral Name: oom_monitor.sh
# Spectral PID: 32, Spectral Name: run.sh
# Spectral PID: 35, Spectral Name: kernel_manager_proxy
# Spectral PID: 61, Spectral Name: python3
# Spectral PID: 62, Spectral Name: colab-fileshim.
# Spectral PID: 79, Spectral Name: jupyter-noteboo
# Spectral PID: 80, Spectral Name: dap_multiplexer
# Spectral PID: 2197, Spectral Name: python3
# Spectral PID: 2264, Spectral Name: python3
# Spectral PID: 9517, Spectral Name: language_service
# Spectral PID: 9522, Spectral Name: node
# Spectral PID: 17870, Spectral Name: python3
# Spectral PID: 17874, Spectral Name: sleep
# Number 2 (big size)
# Number 3 (big size)
# Number 4 (big size)
# Number 5 (big size)
# Number 6 (big size)
# Number 7 (big size)
# Number 8 (big size)
# Number 9 (big size)
# ...

# %% [markdown]
# **Name:-** Nagaraju Naveen Kumar Varma
#
#
# ---
#
#
# **Class:-** 1MSAIM
#
#
# ---
#
#
# **Register number:-** 2348535
#
# ----
#
# **Date of Submission:-** 04/10/2023
#
# -----
#
# # **ML - Component 2**

# %% [markdown]
# # **Importing the libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Data Loading and Inspection**

# %%
# Load the dataset
df = pd.read_csv('/content/HousingData.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.shape
# Out:
# (506, 14)

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# # **Missing Values**
#
#  - Identify and count the missing values in the dataset.

# %%
missing_values_count = df.isnull().sum()

# %%
columns_with_missing_values = missing_values_count[missing_values_count > 0].index.tolist()

# %%
print("Columns with missing values:")
print(columns_with_missing_values)
print("\nMissing values count for each column:")
print(missing_values_count)
# Out:
# Columns with missing values:
# ['CRIM', 'ZN', 'INDUS', 'CHAS', 'AGE', 'LSTAT']
#
# Missing values count for each column:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %% [markdown]
# # **1. Data Exploration and Visualization**

# %%
# Scatter plot of CRIM (crime rate) vs MEDV (median home value)
plt.figure(figsize=(10, 6))
plt.scatter(df['CRIM'], df['MEDV'], alpha=0.7, color='red')
plt.xlabel('Per Capita Crime Rate (CRIM)')
plt.ylabel('Median Home Value (MEDV)')
plt.title('CRIM vs MEDV Scatter Plot')
plt.show()

# Scatter plot of AGE (proportion of owner-occupied units built prior to 1940) vs MEDV (median home value)
plt.figure(figsize=(10, 6))
plt.scatter(df['AGE'], df['MEDV'], alpha=0.7, color='green')
plt.xlabel('Proportion of Owner-Occupied Units Built Prior to 1940 (AGE)')
plt.ylabel('Median Home Value (MEDV)')
plt.title('AGE vs MEDV Scatter Plot')
plt.show()

# %%
# Visualize data distributions
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")
sns.boxplot(data=df, orient='h')
plt.title('Boxplot of Housing Attributes')
plt.show()

# Scatter plot of RM (average number of rooms) vs MEDV (median home value)
plt.figure(figsize=(10, 6))
plt.scatter(df['RM'], df['MEDV'], alpha=0.7)
plt.xlabel('Average Number of Rooms per Dwelling (RM)')
plt.ylabel('Median Home Value (MEDV)')
plt.title('RM vs MEDV Scatter Plot')
plt.show()

# %% [markdown]
# # **2. Data Preprocessing and Feature Selection**

# %% [markdown]
# ### **Feature Selection:**
# ###### **Explain the process of selecting relevant features in building a logistic regression model for predicting home values. Which housing attributes do you believe are most relevant for the task, and why?**
#
# In the case of the Boston Housing dataset, relevant features for predicting home values (MEDV) could include:
#
# - **Average Number of Rooms per Dwelling (RM):** More rooms could imply larger houses and potentially higher home values.
# - **Per Capita Crime Rate (CRIM):** Higher crime rates might negatively impact home values in certain neighborhoods.
# - **Nitric Oxides Concentration (NOX)**: Air quality could affect the desirability and hence the value of the property.
# - **Proportion of Owner-Occupied Units Built Prior to 1940 (AGE):** Older properties might have lower values due to maintenance and modernization issues.
#
# **Data Splitting:**
#
# It involves dividing the dataset into training and testing sets. The training set is used to train the model, while the testing set is used to evaluate the model's performance on unseen data. This step is essential to assess the model's generalization and prevent overfitting (the model memorizing the training data but performing poorly on new data). A common split is 70% for training and 30% for testing.

# %% [markdown]
# ### **Data Splitting:**

# %%
from sklearn.model_selection import train_test_split

# Features (X) and target (y) variables
X = df.drop('MEDV', axis=1)
y = df['MEDV']

# Split the dataset into training and testing sets (70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Print the shapes of the training and testing sets
print("Training set shape: X_train - {}, y_train - {}".format(X_train.shape, y_train.shape))
print("Testing set shape: X_test - {}, y_test - {}".format(X_test.shape, y_test.shape))
# Out:
# Training set shape: X_train - (354, 13), y_train - (354,)
# Testing set shape: X_test - (152, 13), y_test - (152,)

# %%
from sklearn.model_selection import train_test_split

# Features (X) and target variable (y)
X = df[['RM', 'CRIM', 'NOX', 'AGE']]  # Selected relevant features
y = df['MEDV']

# Splitting the data into training and testing sets (70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Print the shapes of the training and testing sets
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (354, 4)
# Shape of y_train: (354,)
# Shape of X_test: (152, 4)
# Shape of y_test: (152,)

# %% [markdown]
# # **3. Linear Regression Model Building**

# %%
from sklearn.linear_model import LinearRegression

# Create and train the linear regression model
linear_reg_model = LinearRegression()
linear_reg_model.fit(X_train_selected, y_train)

# Predict median home values on the test set
y_pred = linear_reg_model.predict(X_test_selected)

# Calculate R-squared to evaluate the model
r_squared = linear_reg_model.score(X_test_selected, y_test)
print("R-squared: {:.2f}".format(r_squared))

# Visualize the regression line on a scatter plot of RM vs MEDV
plt.figure(figsize=(10, 6))
plt.scatter(X_test_selected, y_test, color='blue', label='Actual Data')
plt.plot(X_test_selected, linear_reg_model.predict(X_test_selected), color='red', label='Regression Line')
plt.xlabel('Average Number of Rooms per Dwelling (RM)')
plt.ylabel('Median Home Value (MEDV)')
plt.title('Linear Regression: RM vs MEDV')
plt.legend()
plt.show()
# Out:
# R-squared: 0.46

# %% [markdown]
# # **4. Model Evaluation and Interpretation**

# %% [markdown]
# #### **Mean Squared Error (MSE):**
# Calculate and present the mean squared error for the model on the testing data. Explain the significance of MSE as an evaluation metric for predicting home values.

# %%
from sklearn.metrics import mean_squared_error

# Calculate Mean Squared Error (MSE) for the linear regression model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE): {:.2f}".format(mse))
# Out:
# Mean Squared Error (MSE): 40.35

# %% [markdown]
# **Significance:**
# It provides a quantitative measure of how well the model predicts median home values based on the average number of rooms. A lower MSE indicates a better fit, and in the context of predicting home values, it signifies the average squared difference between the predicted and actual home values.

# %% [markdown]
# #### **Coefficient Interpretation:**
# Interpret the coefficients derived from the logistic regression model. Specifically, what does the coefficient for the number of rooms (RM) signify in terms of its influence on home values?

# %%
from sklearn.linear_model import LinearRegression

# Features (X) and target (y) variables
X = df[['RM']]  # Using only 'RM' as a feature
y = df['MEDV']

# Train a linear regression model
regressor = LinearRegression()
regressor.fit(X, y)

# Coefficients
coefficient_RM = regressor.coef_[0]

# Interpretation of the coefficient for 'RM'
print("Coefficient for RM:", coefficient_RM)
print("For a one-unit increase in RM, the median home value (MEDV) is expected to change by approximately $", round(coefficient_RM * 1000, 2))
# Out:
# Coefficient for RM: 9.10210898118031
# For a one-unit increase in RM, the median home value (MEDV) is expected to change by approximately $ 9102.11

# %% [markdown]
# # **5. Feature Transformation and Interaction**

# %%
# Logarithmic transformation of CRIM
df['CRIM_log'] = np.log(df['CRIM'])

# %%
# Creating the feature interaction 'RM_INDUS'
df['RM_INDUS'] = df['RM'] * df['INDUS']

# %% [markdown]
# # **6. Cost Function and Regularization**

# %% [markdown]
# #### **Cost Function Explanation:**
#
# **Describe the concept of a cost function in logistic regression and its relationship with regularization.**
#
# In logistic regression, a cost function measures the difference between predicted probabilities and actual class labels. The goal is to minimize this function, enabling the model to accurately predict binary outcomes. Regularization is a technique used to prevent overfitting by adding a penalty term to the cost function. It helps balance model complexity and accuracy by discouraging excessive reliance on any particular feature, promoting a more generalized model. The regularization term controls the influence of features, influencing the model's fitting process.
